# %% [markdown]
# # Big O Notation

# %% [markdown]
# ### Make a new Jupyter notebook named big_o_notation.ipynb
#
# - Title your chart "Big O Notation"
# - Label your x axis "Elements"
# - Label your y axis "Operations"
# - Label your curves or make a legend for the curves
# - Use LaTex notation where possible
#
# Curves to graph:
#
# - y = 0n + 1 and label the curve 'O(1)'
# - y = log(n) and label the curve 'O(log n)'
# - y = n and label the curve 'O(n)'
# - y = n * log(n) and label it 'O(n log n)'
# - y = $n^2$ and label it 'O($n^2$)'
# - y = $2^n$ and label it 'O($2^n$)'
# - y = n! and label it 'O(n!)'
# - y = $n^n$ and label it 'O($n^n$)'

# %%
#import pyplot module as alias plt
import matplotlib.pyplot as plt  

#import other libraries 
import numpy as np
import math
from random import randint
import random
import pandas as pd

# %%
plt.figure(figsize = (20, 14))

n = range(0, 25)
y1 = [0 * n + 1 for n in n]
y2 = [np.log(n) for n in n]
y3 = [n for n in x]
y4 = [n * np.log(n) for n in n]
y5 = [n ** 2 for n in n]
y6 = [2 ** n for n in n]
y7 = [math.factorial(n) for n in n]
y8 = [n ** n for n in n]

plt.plot(n, y1, label = 'O(1)', color = 'crimson')
plt.plot(n, y2, label = 'O(log n)', color = 'steelblue')
plt.plot(n, y3, label = 'O(n)', color = 'darkgoldenrod')
plt.plot(n, y4, label = 'O(n log n)', color = 'olive')
plt.plot(n, y5, label = 'O($n^2$)', color = 'teal')
plt.plot(n, y6, label = 'O($2^n$)', color = 'blueviolet')
plt.plot(n, y7, label = 'O(n!)', color = 'cadetblue')
plt.plot(n, y8, label = 'O($n^n$)', color = 'firebrick')

plt.title('Big O Notation', fontsize = 32)
plt.xlabel('Elements', fontsize = 20)
plt.ylabel('Operations', fontsize = 20)
plt.grid('True', ls = '--')
plt.xlim(0, 25)
plt.ylim(0, 25)

plt.legend(fontsize = 14);
# Out:
# /Users/davidrodriguez/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """
# /Users/davidrodriguez/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys
# /Users/davidrodriguez/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in double_scalars
#   import sys

# %% [markdown]
# ### Bonus 1: Write the code necessary to write your name on a chart. Use box letters.

# %%
w = np.arange(-10, 10, 0.01)
z = w**2
  
plt.xlabel("x", fontsize = 15)
plt.ylabel("f(x)",fontsize = 15)
  
#Adding text inside a rectangular box by using the keyword 'bbox'
plt.text(-6, 60, 'David Rodriguez', fontsize = 22,  
         bbox = dict(facecolor = 'lavender', alpha = 0.5))
  
plt.plot(w, z, c = 'crimson')
  
plt.show()

# %% [markdown]
# ### Bonus 2: Use curves for letters in your n ame that have curves in them.
